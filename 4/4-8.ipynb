# %%
class Animal:
  def bark(self):
      print('bark')

class Mammal:
  def feed(self):
      print('feed')

class Cat(Animal, Mammal):
  def name(self):
      print('cat')

cat = Cat()
cat.bark()
cat.feed()
cat.name()
# Out:
# bark
# feed
# cat
