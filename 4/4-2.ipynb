# %%
class  Car(object):
  """
  car info
  """
  def  __init__(self, company, details):
    self._company = company
    self._details = details

  def  __str__(self):
    return  f"str : {self._company}, {self._details}"

  def  __repr__(self):
    return  f"repr : {self._company}, {self._details}"

  def  detail_info(self):
    print(f"id : {id(self)}")
    print(f'car info : {self._details.get("color")}')

  def  __del__(self):
    print("destruction")


car1 = Car("fer", {"color": "white"})
car2 = Car("bmw", {"color": "white"})
car3 = Car("audi", {"color": "white"})

print(id(car1))
print(id(car2))
print(id(car3))

print(car1._company == car2._company)
print(car1 is car2)

print(car1.__dict__)
print(car1.__doc__)
print(str(car1))
print(repr(car1))

car1.detail_info()
car2.detail_info()

print(id(car1.__class__), id(car2.__class__))
# Out:
# 133636122030720
# 133636122032064
# 133636122031920
# False
# False
# {'_company': 'fer', '_details': {'color': 'white'}}
#
#   car info
#
# str : fer, {'color': 'white'}
# repr : fer, {'color': 'white'}
# id : 133636122030720
# car info : white
# id : 133636122032064
# car info : white
# 96518879030112 96518879030112
# destruction
# destruction
# destruction

# %%
class  MyFunc:
	def  __call__(self, *args, **kwargs):
		print("call")

myfunc = MyFunc()
myfunc()
# Out:
# call

# %%
class  MyFunc:
	def  __getattribute__(self, att):
		print(att, "attach")
myfunc = MyFunc()
myfunc.data
# Out:
# data attach
